# %%
pip install pgmpy
# Out:
# Requirement already satisfied: pgmpy in c:\users\hp\anaconda3\lib\site-packages (0.1.24)
# Requirement already satisfied: pyparsing in c:\users\hp\anaconda3\lib\site-packages (from pgmpy) (3.0.4)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from pgmpy) (1.7.3)
# Requirement already satisfied: statsmodels in c:\users\hp\anaconda3\lib\site-packages (from pgmpy) (0.13.2)
# Requirement already satisfied: opt-einsum in c:\users\hp\anaconda3\lib\site-packages (from pgmpy) (3.3.0)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from pgmpy) (1.22.4)
# Requirement already satisfied: networkx in c:\users\hp\anaconda3\lib\site-packages (from pgmpy) (2.7.1)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (from pgmpy) (4.64.0)
# Requirement already satisfied: torch in c:\users\hp\anaconda3\lib\site-packages (from pgmpy) (2.0.0)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (from pgmpy) (1.4.2)
# Requirement already satisfied: scikit-learn in c:\users\hp\anaconda3\lib\site-packages (from pgmpy) (1.0.2)
# Requirement already satisfied: joblib in c:\users\hp\anaconda3\lib\site-packages (from pgmpy) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas->pgmpy) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas->pgmpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->pgmpy) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn->pgmpy) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\hp\anaconda3\lib\site-packages (from statsmodels->pgmpy) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\hp\anaconda3\lib\site-packages (from statsmodels->pgmpy) (21.3)
# Requirement already satisfied: typing-extensions in c:\users\hp\anaconda3\lib\site-packages (from torch->pgmpy) (4.5.0)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from torch->pgmpy) (3.6.0)
# Requirement already satisfied: sympy in c:\users\hp\anaconda3\lib\site-packages (from torch->pgmpy) (1.10.1)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from torch->pgmpy) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->torch->pgmpy) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\hp\anaconda3\lib\site-packages (from sympy->torch->pgmpy) (1.2.1)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm->pgmpy) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import csv 
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.models import BayesianNetwork
from pgmpy.inference import VariableElimination

data = pd.read_csv("C:/Users/hp/Downloads/Practical_Data/heartdisease.csv")
heart_disease = pd.DataFrame(data)
print(heart_disease)

print('\nSample instances from the dataset are given below')
print(heart_disease.head())

print('\n Attributes and datatypes')
print(heart_disease.dtypes)

model = BayesianNetwork([
    ('age', 'Lifestyle'),
    ('Gender', 'Lifestyle'),
    ('Family', 'heartdisease'),
    ('diet', 'cholestrol'),
    ('Lifestyle', 'diet'),
    ('cholestrol', 'heartdisease'),
    ('diet', 'cholestrol')
])

print('\nLearning CPD using Maximum likelihood estimators')
model.fit(heart_disease, estimator=MaximumLikelihoodEstimator)

print('\n Inferencing with Bayesian Network:')
HeartDisease_infer = VariableElimination(model)

print('\n 1. Probability of HeartDisease given evidence = age')
q1= HeartDisease_infer.query(variables=['heartdisease'],evidence={'age':1})
print(q1)

print('\n 2. Probability of HeartDisease given evidence= diet')
q2=HeartDisease_infer.query(variables=['heartdisease'],evidence={'diet':1})
print(q2)
# Out:
#     age  Gender  Family  diet  Lifestyle  cholestrol  heartdisease
# 0     0       0       1     1          3           0             1
# 1     0       1       1     1          3           0             1
# 2     1       0       0     0          2           1             1
# 3     4       0       1     1          3           2             0
# 4     3       1       1     0          0           2             0
# 5     2       0       1     1          1           0             1
# 6     4       0       1     0          2           0             1
# 7     0       0       1     1          3           0             1
# 8     3       1       1     0          0           2             0
# 9     1       1       0     0          0           2             1
# 10    4       1       0     1          2           0             1
# 11    4       0       1     1          3           2             0
# 12    2       1       0     0          0           0             0
# 13    2       0       1     1          1           0             1
# 14    3       1       1     0          0           1             0
# 15    0       0       1     0          0           2             1
# 16    1       1       0     1          2           1             1
# 17    3       1       1     1          0           1             0
# 18    4       0       1     1          3           2             0
#
# Sample instances from the dataset are given below
#    age  Gender  Family  diet  Lifestyle  cholestrol  heartdisease
# 0    0       0       1     1          3           0             1
# 1    0       1       1     1          3           0             1
# 2    1       0       0     0          2           1             1
# 3    4       0       1     1          3           2             0
# 4    3       1       1     0          0           2             0
#
#  Attributes and datatypes
# age             int64
# Gender          int64
# Family          int64
# diet            int64
# Lifestyle       int64
# cholestrol      int64
# heartdisease    int64
# dtype: object
#
# Learning CPD using Maximum likelihood estimators
#
#  Inferencing with Bayesian Network:
#
#  1. Probability of HeartDisease given evidence = age
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.4614 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.5386 |
# +-----------------+---------------------+
#
#  2. Probability of HeartDisease given evidence= diet
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.3732 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.6268 |
# +-----------------+---------------------+
