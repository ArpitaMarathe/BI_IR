# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df_train = pd.read_csv("C:/Users/hp/Downloads/Practical_Data/train.csv")
print(df_train.shape)
df_test = pd.read_csv("C:/Users/hp/Downloads/Practical_Data/test.csv")
print(df_test.shape)
# Out:
# (38, 7131)
# (34, 7131)

# %%
df_train.head()
# Out:
#    Unnamed: 0  AFFX-BioB-5_at  AFFX-BioB-M_at  AFFX-BioB-3_at  AFFX-BioC-5_at  \
# 0           0            -214            -153             -58              88
# 1           1            -139             -73              -1             283
# 2           2             -76             -49            -307             309
# 3           3            -135            -114             265              12
# 4           4            -106            -125             -76             168
#
#    AFFX-BioC-3_at  AFFX-BioDn-5_at  AFFX-BioDn-3_at  AFFX-CreX-5_at  \
# 0            -295             -558              199            -176
# 1            -264             -400             -330            -168
# 2            -376             -650               33            -367
# 3            -419             -585              158            -253
# 4            -230             -284                4            -122
#
#    AFFX-CreX-3_at  ...  U58516_at  U73738_at  X06956_at  X16699_at  X83863_at  \
# 0             252  ...        511       -125        389        -37        793
# 1             101  ...        837        -36        442        -17        782
# 2             206  ...       1199         33        168         52       1138
# 3              49  ...        835        218        174       -110        627
# 4              70  ...        649         57        504        -26        250
#
#    Z17240_at  L49218_f_at  M71243_f_at  Z78285_f_at  cancer
# 0        329           36          191          -37       0
# 1        295           11           76          -14       0
# 2        777           41          228          -41       0
# 3        170          -50          126          -91       0
# 4        314           14           56          -25       0
#
# [5 rows x 7131 columns]

# %%
df_test.head()
# Out:
#    Unnamed: 0  AFFX-BioB-5_at  AFFX-BioB-M_at  AFFX-BioB-3_at  AFFX-BioC-5_at  \
# 0           0            -342            -200              41             328
# 1           1             -87            -248             262             295
# 2           2              22            -153              17             276
# 3           3            -243            -218            -163             182
# 4           4            -130            -177             -28             266
#
#    AFFX-BioC-3_at  AFFX-BioDn-5_at  AFFX-BioDn-3_at  AFFX-CreX-5_at  \
# 0            -224             -427             -656            -292
# 1            -226             -493              367            -452
# 2            -211             -250               55            -141
# 3            -289             -268             -285            -172
# 4            -170             -326             -222             -93
#
#    AFFX-CreX-3_at  ...  U58516_at  U73738_at  X06956_at  X16699_at  X83863_at  \
# 0             137  ...       1023         67        214       -135       1074
# 1             194  ...        529       -295        352        -67         67
# 2               0  ...        399         16        558         24        893
# 3              52  ...        277          6         81          2        722
# 4              10  ...        643         51        450        -46        612
#
#    Z17240_at  L49218_f_at  M71243_f_at  Z78285_f_at  cancer
# 0        475           48          168          -70       0
# 1        263          -33          -33          -21       0
# 2        297            6         1971          -42       0
# 3        170            0          510          -73       0
# 4        370           29          333          -19       0
#
# [5 rows x 7131 columns]

# %% [markdown]
# # Splitting the dataset

# %%
x_train = df_train.iloc[:,:-1]
y_train = df_train.iloc[:,-1:]
x_test = df_test.iloc[:,:-1]
y_test = df_test.iloc[:,-1:]
x_train.head()
# Out:
#    Unnamed: 0  AFFX-BioB-5_at  AFFX-BioB-M_at  AFFX-BioB-3_at  AFFX-BioC-5_at  \
# 0           0            -214            -153             -58              88
# 1           1            -139             -73              -1             283
# 2           2             -76             -49            -307             309
# 3           3            -135            -114             265              12
# 4           4            -106            -125             -76             168
#
#    AFFX-BioC-3_at  AFFX-BioDn-5_at  AFFX-BioDn-3_at  AFFX-CreX-5_at  \
# 0            -295             -558              199            -176
# 1            -264             -400             -330            -168
# 2            -376             -650               33            -367
# 3            -419             -585              158            -253
# 4            -230             -284                4            -122
#
#    AFFX-CreX-3_at  ...  U48730_at  U58516_at  U73738_at  X06956_at  X16699_at  \
# 0             252  ...        185        511       -125        389        -37
# 1             101  ...        169        837        -36        442        -17
# 2             206  ...        315       1199         33        168         52
# 3              49  ...        240        835        218        174       -110
# 4              70  ...        156        649         57        504        -26
#
#    X83863_at  Z17240_at  L49218_f_at  M71243_f_at  Z78285_f_at
# 0        793        329           36          191          -37
# 1        782        295           11           76          -14
# 2       1138        777           41          228          -41
# 3        627        170          -50          126          -91
# 4        250        314           14           56          -25
#
# [5 rows x 7130 columns]

# %%
y_train.head()
# Out:
#    cancer
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# # Training the model

# %%
rf_model = RandomForestClassifier(random_state=0)

rf_model.fit(x_train, y_train.values)

rf_pred = rf_model.predict(x_test)
accuracy_score(y_test, rf_pred)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17812\1768619533.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_model.fit(x_train, y_train.values)
# 0.6470588235294118

# %%
confusion_matrix(y_test,rf_pred)
# Out:
# array([[18,  2],
#        [10,  4]], dtype=int64)
